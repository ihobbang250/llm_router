# %%
from datasets import load_dataset
import pandas as pd

# 1. 데이터셋 불러오기
ds = load_dataset("TheFinAI/flare-finqa")  #  [oai_citation:0‡Hugging Face](https://huggingface.co/datasets/TheFinAI/flare-finqa?utm_source=chatgpt.com)

# 2. 예를 들어 ‘test’ 스플릿만 사용한다고 가정
df = pd.DataFrame(ds["valid"])

# 3. CSV로 저장
df.to_csv("flare_finqa_valid.csv", index=False, encoding="utf-8")
